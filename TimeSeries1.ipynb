# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
#https://www.analyticsvidhya.com/blog/2016/01/complete-tutorial-learn-data-science-python-scratch-2/

# %%
data = pd.read_csv('data/interest_over_time2.csv')
data
# Out:
#         caldate  bahubali  dangal  jab harry met sejal  tubelight  \
# 0    2012-08-19         0       0                    0          0
# 1    2012-08-26         0       0                    0          0
# 2    2012-09-02         0       0                    0          0
# 3    2012-09-09         0       0                    0          0
# 4    2012-09-16         0       0                    0          0
# 5    2012-09-23         0       0                    0          0
# 6    2012-09-30         0       0                    0          0
# 7    2012-10-07         0       0                    0          0
# 8    2012-10-14         0       0                    0          0
# 9    2012-10-21         0       0                    0          0
# 10   2012-10-28         0       0                    0          0
# 11   2012-11-04         0       0                    0          0
# 12   2012-11-11         0       0                    0          0
# ...

# %%
headers = ['caldate', 'bahubali', 'dangal']
dtypes = {'col1': 'str', 'col2': 'int', 'col3': 'int'}
parse_dates = ['caldate']
data = pd.read_csv('data/interest_over_time2.csv', sep='\,', dtype=dtypes, parse_dates=parse_dates)
# Out:
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
print (data.head())
# Out:
#      caldate  bahubali  dangal  jab harry met sejal  tubelight  \
# 0 2012-08-19         0       0                    0          0
# 1 2012-08-26         0       0                    0          0
# 2 2012-09-02         0       0                    0          0
# 3 2012-09-09         0       0                    0          0
# 4 2012-09-16         0       0                    0          0
#
#    toilet ek prem katha  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0                     0         NaN         NaN         NaN        NaN
# 1                     0         NaN         NaN         NaN        NaN
# 2                     0         NaN         NaN         NaN        NaN
# 3                     0         NaN         NaN         NaN        NaN
# 4                     0         NaN         NaN         NaN        NaN

# %%
print ('\n Data Types:')
print (data.dtypes)
# Out:
#  Data Types:
# caldate                 datetime64[ns]
# bahubali                         int64
# dangal                           int64
# jab harry met sejal              int64
# tubelight                        int64
# toilet ek prem katha             int64
# Unnamed: 6                     float64
# Unnamed: 7                     float64
# Unnamed: 8                     float64
# Unnamed: 9                      object
# dtype: object

# %%
data[['caldate','bahubali','dangal']]
# Out:
#        caldate  bahubali  dangal
# 0   2012-08-19         0       0
# 1   2012-08-26         0       0
# 2   2012-09-02         0       0
# 3   2012-09-09         0       0
# 4   2012-09-16         0       0
# 5   2012-09-23         0       0
# 6   2012-09-30         0       0
# 7   2012-10-07         0       0
# 8   2012-10-14         0       0
# 9   2012-10-21         0       0
# 10  2012-10-28         0       0
# 11  2012-11-04         0       0
# 12  2012-11-11         0       0
# 13  2012-11-18         0       0
# 14  2012-11-25         0       0
# 15  2012-12-02         0       0
# 16  2012-12-09         0       0
# 17  2012-12-16         0       0
# 18  2012-12-23         0       0
# 19  2012-12-30         0       0
# 20  2013-01-06         0       0
# 21  2013-01-13         0       0
# 22  2013-01-20         0       0
# 23  2013-01-27         0       0
# 24  2013-02-03         0       0
# 25  2013-02-10         0       0
# 26  2013-02-17         0       0
# ...

# %%
newdf = data[data['caldate'] >= "2016-05-20"]

# %%
newdf
# Out:
#        caldate  bahubali  dangal  jab harry met sejal  tubelight  \
# 196 2016-05-22         1       0                    0          0
# 197 2016-05-29         1       0                    0          0
# 198 2016-06-05         1       0                    0          0
# 199 2016-06-12         2       1                    0          0
# 200 2016-06-19         2       0                    0          0
# 201 2016-06-26         2       0                    0          0
# 202 2016-07-03         2       1                    0          0
# 203 2016-07-10         2       1                    0          0
# 204 2016-07-17         2       1                    0          0
# 205 2016-07-24         2       0                    0          0
# 206 2016-07-31         2       0                    0          0
# 207 2016-08-07         2       0                    0          0
# 208 2016-08-14         2       0                    0          0
# ...

# %%
 pd.to_datetime(newdf["caldate"])
# Out:
# 196   2016-05-22
# 197   2016-05-29
# 198   2016-06-05
# 199   2016-06-12
# 200   2016-06-19
# 201   2016-06-26
# 202   2016-07-03
# 203   2016-07-10
# 204   2016-07-17
# 205   2016-07-24
# 206   2016-07-31
# 207   2016-08-07
# 208   2016-08-14
# 209   2016-08-21
# 210   2016-08-28
# 211   2016-09-04
# 212   2016-09-11
# 213   2016-09-18
# 214   2016-09-25
# 215   2016-10-02
# 216   2016-10-09
# 217   2016-10-16
# 218   2016-10-23
# 219   2016-10-30
# 220   2016-11-06
# 221   2016-11-13
# 222   2016-11-20
# 223   2016-11-27
# 224   2016-12-04
# 225   2016-12-11
#          ...
# 257   2017-07-23
# 258   2017-07-30
# 259   2017-08-06
# 260   2017-08-13
# 261   2017-08-16
# 262   2017-08-19
# 263   2017-08-22
# 264   2017-08-25
# 265   2017-08-28
# 266   2017-08-31
# 267   2017-09-03
# 268   2017-09-06
# 269   2017-09-09
# 270   2017-09-12
# 271   2017-09-15
# 272   2017-09-18
# 273   2017-09-21
# 274   2017-09-24
# 275   2017-09-27
# 276   2017-09-30
# 277   2017-10-03
# ...

# %%
 newdf= newdf.set_index('caldate')

# %%
ba2df= newdf.loc['2016-08-21':'2017-10-13'] #-250 +107
dadf= newdf.loc['2016-04-17':'2017-06-09']

# %%
#>> titanic.loc[:,['sex','age','fare']]
#titanic.iloc[:,[2,3,6]]
#dadf.iloc[:,0:2]
#dadf.loc[:,['bahubali','dangal']]
ba2df = ba2df.loc[:,['bahubali']]
ba2df
# Out:
#             bahubali
# caldate
# 2016-08-21         2
# 2016-08-28         2
# 2016-09-04         1
# 2016-09-11         2
# 2016-09-18         1
# 2016-09-25         2
# 2016-10-02         2
# 2016-10-09         2
# 2016-10-16         3
# 2016-10-23         3
# 2016-10-30         2
# 2016-11-06         2
# 2016-11-13         2
# 2016-11-20         3
# 2016-11-27         2
# 2016-12-04         2
# 2016-12-11         2
# 2016-12-18         2
# 2016-12-25         2
# 2017-01-01         2
# 2017-01-08         2
# 2017-01-15         2
# 2017-01-22         2
# 2017-01-29         2
# 2017-02-05         2
# 2017-02-12         2
# 2017-02-19         2
# 2017-02-26         3
# 2017-03-05         3
# 2017-03-12        10
# ...              ...
# 2017-06-11        17
# 2017-06-18        15
# 2017-06-25        14
# 2017-07-02        12
# 2017-07-09        10
# 2017-07-16        10
# 2017-07-23         9
# 2017-07-30         8
# 2017-08-06         8
# 2017-08-13         9
# 2017-08-16         0
# ...

# %%
dadf = dadf.loc[:,['dangal']]
dadf
# Out:
#             dangal
# caldate
# 2016-05-22       0
# 2016-05-29       0
# 2016-06-05       0
# 2016-06-12       1
# 2016-06-19       0
# 2016-06-26       0
# 2016-07-03       1
# 2016-07-10       1
# 2016-07-17       1
# 2016-07-24       0
# 2016-07-31       0
# 2016-08-07       0
# 2016-08-14       0
# 2016-08-21       0
# 2016-08-28       0
# 2016-09-04       0
# 2016-09-11       0
# 2016-09-18       0
# 2016-09-25       0
# 2016-10-02       0
# 2016-10-09       0
# 2016-10-16       3
# 2016-10-23       2
# 2016-10-30       1
# 2016-11-06       1
# 2016-11-13       2
# 2016-11-20       3
# 2016-11-27       3
# 2016-12-04       3
# 2016-12-11       4
# 2016-12-18      35
# 2016-12-25      78
# 2017-01-01      45
# 2017-01-08      29
# 2017-01-15      21
# 2017-01-22      16
# 2017-01-29      12
# 2017-02-05      10
# 2017-02-12       8
# 2017-02-19       8
# 2017-02-26       7
# 2017-03-05       6
# 2017-03-12       4
# 2017-03-19       4
# 2017-03-26       4
# 2017-04-02       3
# ...

# %%
plt.plot(dadf)

# %%
plt.plot(ba2df)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=14,center =False)
    rolstd = pd.rolling_std(timeseries, window=14,center =False)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
  #  dftest = adfuller(timeseries, autolag='AIC')
  #  dfoutput = pd.Series(dftest[0:1], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
  #  for key,value in dftest[4].items():
  #      dfoutput['Critical Value (%s)'%key] = value
  #  print (dfoutput)

# %%
test_stationarity(ba2df)
# Out:
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=14).mean()
#   """
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=14).std()
# Results of Dickey-Fuller Test:

# %%
test_stationarity(dadf)
# Out:
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=14).mean()
#   """
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,window=14).std()
# Results of Dickey-Fuller Test:

# %%
import seaborn as sns
ba2df.plot(label='Raw')
ba2df.rolling(28).mean().plot(label='28D MA')
ba2df.expanding().mean().plot(label='Expanding Average')
ba2df.ewm(alpha=0.03).mean().plot(label='EWMA($\\alpha=.03$)')

plt.legend(bbox_to_anchor=(1.25, .5))
plt.tight_layout()
plt.ylabel("Close ($)")
sns.despine()

# %%
import seaborn as sns
dadf.plot(label='Raw')
dadf.rolling(28).mean().plot(label='28D MA')
dadf.expanding().mean().plot(label='Expanding Average')
dadf.ewm(alpha=0.03).mean().plot(label='EWMA($\\alpha=.03$)')

plt.legend(bbox_to_anchor=(1.25, .5))
plt.tight_layout()
plt.ylabel("Close ($)")
sns.despine()

# %%
ba2df.boxplot(column='bahubali')

# %%
from numpy import mean
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
series = ba2df
# prepare situation
X = series.values
window = 14
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
	length = len(history)
	yhat = mean([history[i] for i in range(length-window,length)])
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# zoom plot
pyplot.plot(test[0:100])
pyplot.plot(predictions[0:100], color='red')
pyplot.show()
# Out:
# predicted=2.071429, expected=2.000000
# predicted=2.071429, expected=2.000000
# predicted=2.071429, expected=2.000000
# predicted=2.142857, expected=2.000000
# predicted=2.142857, expected=2.000000
# predicted=2.214286, expected=2.000000
# predicted=2.214286, expected=2.000000
# predicted=2.214286, expected=2.000000
# predicted=2.214286, expected=2.000000
# predicted=2.142857, expected=2.000000
# predicted=2.071429, expected=2.000000
# predicted=2.071429, expected=2.000000
# predicted=2.071429, expected=2.000000
# predicted=2.071429, expected=3.000000
# predicted=2.071429, expected=3.000000
# predicted=2.142857, expected=10.000000
# predicted=2.714286, expected=7.000000
# predicted=3.071429, expected=11.000000
# predicted=3.714286, expected=7.000000
# predicted=4.071429, expected=9.000000
# predicted=4.571429, expected=9.000000
# predicted=5.071429, expected=61.000000
# predicted=9.285714, expected=100.000000
# predicted=16.285714, expected=68.000000
# ...

# %%
from pandas import Series
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2016/01/complete-tutorial-learn-data-science-python-scratch-2/

# %%
square_list = [5,6,7,8]

# %%
square_list
# Out:
# [5, 6, 7, 8]

# %%
square_list[1:3]
# Out:
# [6, 7]

# %%
square_list[1:]
# Out:
# [6, 7, 8]

# %%
square_list[2:]
# Out:
# [7, 8]

# %%
square_list[:1]
# Out:
# [5]

# %%
square_list[:2]
# Out:
# [5, 6]

# %%
greeting = "hello"

# %%
greeting[1]
# Out:
# 'e'

# %%
greeting[2:]
# Out:
# 'llo'

# %%
greeting[:2]
# Out:
# 'he'

# %%
tuple_ex = 4,3,2,1

# %%
tuple_ex
# Out:
# (4, 3, 2, 1)

# %%
tuple_ex[2:]
# Out:
# (2, 1)

# %%
dict_ex ={'Kunal':22,'Japan':11,'gopan':1}

# %%
dict_ex
# Out:
# {'Japan': 11, 'Kunal': 22, 'gopan': 1}

# %%
dict_ex['Kunal']
# Out:
# 22

# %%
for i in [tuple_ex]:
  print(i)
# Out:
# (4, 3, 2, 1)

# %%
ba2df.describe()
# Out:
#          bahubali
# count   52.000000
# mean    11.269231
# std     19.023325
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%     10.000000
# max    100.000000

# %%
dadf.describe()
# Out:
#           dangal
# count  47.000000
# mean    6.787234
# std    14.215632
# min     0.000000
# 25%     0.000000
# 50%     2.000000
# 75%     5.000000
# max    78.000000

# %%
ba2df['bahubali'].value_counts()
#frequency
# Out:
# 2      22
# 3       5
# 9       4
# 10      3
# 1       2
# 7       2
# 8       2
# 11      1
# 68      1
# 61      1
# 49      1
# 14      1
# 15      1
# 17      1
# 20      1
# 27      1
# 35      1
# 100     1
# 12      1
# Name: bahubali, dtype: int64

# %%
ba2df['bahubali'].hist(bins=30)

# %%
temp1 = ba2df['bahubali'].value_counts(ascending=True)
temp2 = ba2df.pivot_table(values='bahubali',index=['caldate'],aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print ('Frequency Table for Credit History:' )
print (temp1)

print ('\nProbility of getting loan for each Credit History class:' )
print (temp2)
# Out:
# Frequency Table for Credit History:
# 12      1
# 100     1
# 35      1
# 27      1
# 20      1
# 17      1
# 15      1
# 14      1
# 49      1
# 61      1
# 68      1
# 11      1
# 8       2
# 7       2
# 1       2
# 10      3
# 9       4
# 3       5
# 2      22
# Name: bahubali, dtype: int64
#
# Probility of getting loan for each Credit History class:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# # UNDERSTANDING AND APPLIYING LINEAR REGRESSION

# %%
#In cooerdination with excel LR

# %%
import pandas as pd
import numpy as np

# %%
nasdaqFile = 'DATA_EXL/NASDAQ.csv'
spFile = 'DATA_EXL/S&P_500.csv'
googFile = 'DATA_EXL/GOOG.csv'
oilFile = 'DATA_EXL/USO.csv'
xomFile = 'DATA_EXL/XOM.csv'

# %%
data = pd.read_csv(googFile,sep=",",usecols=[0,5],names=['DATE','PRICE'],header=0)

# %%
data.head()
# Out:
#          DATE       PRICE
# 0  2012-10-01  338.879791
# 1  2012-11-01  347.881042
# 2  2012-12-01  352.369232
# 3  2013-01-01  376.434021
# 4  2013-02-01  399.104065

# %%
#convert these prices to returns

# %%
returns = np.array(data['PRICE'][:-1],np.float)/np.array(data['PRICE'][1:],np.float)-1

# %%
#put returns back in df,nan is a special value nan at the en dof returns array,since there are 1 less ret this makes it null
data["RETURNS"] = np.append(returns,np.nan)

# %%
#data

# %%
#PUT ABOVE CODE IN FUNCTION
def readFile(filename):
    data = pd.read_csv(filename,sep=",",usecols=[0,5],names=['DATE','PRICE'],header=0)
    returns = np.array(data['PRICE'][:-1],np.float)/np.array(data['PRICE'][1:],np.float)-1
    data["RETURNS"] = np.append(returns,np.nan)
    data.index=data["DATE"]
    return data

# %%
googData = readFile(googFile)
nasdaqData = readFile(nasdaqFile)

# %%
googData.head()
# Out:
#                   DATE       PRICE   RETURNS
# DATE
# 2012-10-01  2012-10-01  338.879791 -0.025875
# 2012-11-01  2012-11-01  347.881042 -0.012737
# 2012-12-01  2012-12-01  352.369232 -0.063928
# 2013-01-01  2013-01-01  376.434021 -0.056802
# 2013-02-01  2013-02-01  399.104065  0.008827

# %%
nasdaqData.head()
# Out:
#                   DATE        PRICE   RETURNS
# DATE
# 2012-10-01  2012-10-01  2977.229980 -0.010966
# 2012-11-01  2012-11-01  3010.239990 -0.003070
# 2012-12-01  2012-12-01  3019.510010 -0.039024
# 2013-01-01  2013-01-01  3142.129883 -0.005715
# 2013-02-01  2013-02-01  3160.189941 -0.032848

# %%
XData = nasdaqData['RETURNS'][0:-1].reshape(-1,1)   #LAST VALUE IS NAN SO [0:-1]
# Out:
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
yData = googData['RETURNS'][0:-1]

# %%
from sklearn import datasets,linear_model

# %%
goodGoogModel = linear_model.LinearRegression()

# %%
goodGoogModel.fit(XData,yData) # we have got  aline at end of this
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#MEASURE R square
goodGoogModel.score(XData,yData)
# Out:
# 0.30961180216645512

# %%
goodGoogModel.coef_ #slope
# Out:
# array([ 0.89385145])

# %%
#now examin residuals and other properties

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(XData,yData,color='black')
plt.plot(XData,goodGoogModel.predict(XData),color='blue',linewidth=3)

# %%
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.show()

# %%
#MULTIPLE REGRESSION IN PYTHON

# %%
import pandas as pd
import numpy as np

# %%
nasdaqFile = 'DATA_EXL/NASDAQ.csv'
spFile = 'DATA_EXL/S&P_500.csv'
googFile = 'DATA_EXL/GOOG.csv'
oilFile = 'DATA_EXL/USO.csv'
xomFile = 'DATA_EXL/XOM.csv'

# %%
#PUT price to returns and set up df
def readFile(filename):
    data = pd.read_csv(filename,sep=",",usecols=[0,5],names=['DATE','PRICE'],header=0)
    returns = np.array(data['PRICE'][:-1],np.float)/np.array(data['PRICE'][1:],np.float)-1
    data["RETURNS"] = np.append(returns,np.nan)
    data.index=data["DATE"]
    return data

# %%
from sklearn import datasets,linear_model

# %%
oilData = readFile(oilFile)

# %%
oilDatafilled = oilData['RETURNS'][0:-1]

# %%
nasdaqData = readFile(nasdaqFile)

# %%
nasdaqDatafilled = nasdaqData['RETURNS'][0:-1]

# %%
#nasdaq and oil returns must have corresponding data,retrict the nasdaq array to length of oil array-oil 
#data starts 3 months after nasdaq
nasdaqDatafilled = nasdaqDatafilled[0:len(oilDatafilled)]

# %%
#pass 2 numpy arrays vstack stacks it vertically
combined = np.vstack((nasdaqDatafilled,oilDatafilled))
len(combined)
# Out:
# 2

# %%
combined
# Out:
# array([[ -1.09659064e-02,  -3.07004116e-03,  -3.90244444e-02,
#          -5.71486472e-03,  -3.28475658e-02,  -1.84060930e-02,
#          -3.67833295e-02,   1.54734186e-02,  -6.15271221e-02,
#           1.01674988e-02,  -4.81534740e-02,  -3.78165687e-02,
#          -3.45280132e-02,  -2.79414439e-02,   1.77173707e-02,
#          -4.74082032e-02,   2.59895539e-02,   2.05198548e-02,
#          -3.01841915e-02,  -3.75574619e-02,   8.78997197e-03,
#          -4.59579892e-02,   1.93350411e-02,  -2.96605057e-02,
#          -3.35772280e-02,   1.17355349e-02,   2.17485105e-02,
#          -6.61403407e-02,   1.27833988e-02,  -8.20412749e-03,
#          -2.53666879e-02,   1.66757237e-02,  -2.75744838e-02,
#           6.55700897e-02,   4.16760022e-02,  -8.57956654e-02,
#          -1.07503367e-02,   2.02219836e-02,   8.52761613e-02,
#           1.22862246e-02,  -6.40471260e-02,   1.97870397e-02,
#          -3.49006071e-02,   2.17606991e-02,  -6.18853009e-02,
# ...

# %%
#stacck horizontally

combined = combined.T
len(combined)
# Out:
# 60

# %%
len(combined)
# Out:
# 60

# %%
combined
# Out:
# array([[ -1.09659064e-02,  -2.39557732e-02],
#        [ -3.07004116e-03,  -2.42732402e-02],
#        [ -3.90244444e-02,  -5.41383235e-02],
#        [ -5.71486472e-03,   6.71505727e-02],
#        [ -3.28475658e-02,  -4.86330647e-02],
#        [ -1.84060930e-02,   4.79493366e-02],
#        [ -3.67833295e-02,   1.68659608e-02],
#        [  1.54734186e-02,  -4.59332651e-02],
#        [ -6.15271221e-02,  -8.51177975e-02],
#        [  1.01674988e-02,  -2.91060031e-02],
#        [ -4.81534740e-02,   4.42334352e-02],
#        [ -3.78165687e-02,   6.22657556e-02],
#        [ -3.45280132e-02,   3.67603119e-02],
#        [ -2.79414439e-02,  -5.26614100e-02],
#        [  1.77173707e-02,   1.49425579e-02],
#        [ -4.74082032e-02,  -5.28035627e-02],
#        [  2.59895539e-02,   4.09953539e-03],
#        [  2.05198548e-02,   7.43392070e-03],
#        [ -3.01841915e-02,  -3.60934183e-02],
#        [ -3.75574619e-02,  -3.08642225e-02],
#        [  8.78997197e-03,   7.04846090e-02],
# ...

# %%
#XOM IS OUR y DATA
xomData = readFile(xomFile)

# %%
l
# Out:
# 2

# %%
xomDataFilled = xomData['RETURNS'][0:-1][0:len(oilDatafilled)]

# %%
xomNasdaqOilModel = linear_model.LinearRegression()

# %%
xomNasdaqOilModel.fit(combined,xomDataFilled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#r^2
xomNasdaqOilModel.score(combined,xomDataFilled)
# Out:
# 0.18365594452682932

# %%
#we use statsmodels to check our ways of checkout results of reg,above is a ml model

# %%
import statsmodels.api as sm
# Out:
# /home/vijay/anaconda2/envs/py35/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
X = sm.add_constant(combined)

# %%
X
# Out:
# array([[  1.00000000e+00,  -1.09659064e-02,  -2.39557732e-02],
#        [  1.00000000e+00,  -3.07004116e-03,  -2.42732402e-02],
#        [  1.00000000e+00,  -3.90244444e-02,  -5.41383235e-02],
#        [  1.00000000e+00,  -5.71486472e-03,   6.71505727e-02],
#        [  1.00000000e+00,  -3.28475658e-02,  -4.86330647e-02],
#        [  1.00000000e+00,  -1.84060930e-02,   4.79493366e-02],
#        [  1.00000000e+00,  -3.67833295e-02,   1.68659608e-02],
#        [  1.00000000e+00,   1.54734186e-02,  -4.59332651e-02],
#        [  1.00000000e+00,  -6.15271221e-02,  -8.51177975e-02],
#        [  1.00000000e+00,   1.01674988e-02,  -2.91060031e-02],
#        [  1.00000000e+00,  -4.81534740e-02,   4.42334352e-02],
#        [  1.00000000e+00,  -3.78165687e-02,   6.22657556e-02],
#        [  1.00000000e+00,  -3.45280132e-02,   3.67603119e-02],
#        [  1.00000000e+00,  -2.79414439e-02,  -5.26614100e-02],
#        [  1.00000000e+00,   1.77173707e-02,   1.49425579e-02],
# ...

# %%
model = sm.OLS(xomDataFilled,X)

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                RETURNS   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     6.412
# Date:                Sat, 07 Oct 2017   Prob (F-statistic):            0.00308
# Time:                        22:38:20   Log-Likelihood:                 113.38
# No. Observations:                  60   AIC:                            -220.8
# Df Residuals:                      57   BIC:                            -214.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.005      0.023      0.981      -0.011       0.011
# ...
